# %% [markdown]
# <a href="https://colab.research.google.com/github/izzul112/ML_BMLP_Learning/blob/main/Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
print(tf.__version__)
# Out:
# 2.5.0

# %%
# !wget --no-check-certificate \
  https://dicodingacademy.blob.core.windows.net/picodiploma/ml_pemula_academy/messy-vs-clean-room.zip \
  -O /tmp/messy_vs_clean_room.zip
# Out:
# --2021-07-03 01:15:09--  https://dicodingacademy.blob.core.windows.net/picodiploma/ml_pemula_academy/messy-vs-clean-room.zip
# Resolving dicodingacademy.blob.core.windows.net (dicodingacademy.blob.core.windows.net)... 52.239.197.36
# Connecting to dicodingacademy.blob.core.windows.net (dicodingacademy.blob.core.windows.net)|52.239.197.36|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 70392746 (67M) [application/zip]
# Saving to: ‘/tmp/messy_vs_clean_room.zip’
#
# /tmp/messy_vs_clean 100%[===================>]  67.13M  2.23MB/s    in 19s
#
# 2021-07-03 01:15:29 (3.54 MB/s) - ‘/tmp/messy_vs_clean_room.zip’ saved [70392746/70392746]

# %%
# melakukan ekstraksi pada file zip
import zipfile,os
local_zip = '/tmp/messy_vs_clean_room.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()
 
base_dir = '/tmp/images'
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'val')

# %%
os.listdir('/tmp/images/train')
# Out:
# ['messy', 'clean']

# %%
os.listdir('/tmp/images/val')
# Out:
# ['messy', 'clean']

# %%
# membuat direktori ruangan rapi pada direktori data training
train_clean_dir = os.path.join(train_dir, 'clean')
 
# membuat direktori ruangan berantakan pada direktori data training
train_messy_dir = os.path.join(train_dir, 'messy')
 
# membuat direktori ruangan rapi pada direktori data validasi
validation_clean_dir = os.path.join(validation_dir, 'clean')
 
# membuat direktori ruangan berantakan pada direktori data validasi
validation_messy_dir = os.path.join(validation_dir, 'messy')

# %%
train_datagen = ImageDataGenerator(
                    rescale=1./255,
                    rotation_range=20,
                    horizontal_flip=True,
                    shear_range = 0.2,
                    fill_mode = 'nearest')
 
test_datagen = ImageDataGenerator(
                    rescale=1./255,
                    rotation_range=20,
                    horizontal_flip=True,
                    shear_range = 0.2,
                    fill_mode = 'nearest')

# %%
train_generator = train_datagen.flow_from_directory(
        train_dir,  # direktori data latih
        target_size=(150, 150),  # mengubah resolusi seluruh gambar menjadi 150x150 piksel
        batch_size=4,
        # karena kita merupakan masalah klasifikasi 2 kelas maka menggunakan class_mode = 'binary'
        class_mode='binary')
 
validation_generator = test_datagen.flow_from_directory(
        validation_dir, # direktori data validasi
        target_size=(150, 150), # mengubah resolusi seluruh gambar menjadi 150x150 piksel
        batch_size=4, # karena kita merupakan masalah klasifikasi 2 kelas maka menggunakan class_mode = 'binary'
        class_mode='binary')
# Out:
# Found 192 images belonging to 2 classes.
# Found 20 images belonging to 2 classes.

# %%
# Callback

class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy')>=0.92 and logs.get('val_accuracy')>=0.92):
      print("\nReached 96% accuracy so cancelling training!")
      self.model.stop_training = True

callbacks = myCallback()

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
model.compile(loss='binary_crossentropy',
              optimizer=tf.optimizers.Adam(),
              metrics=['accuracy'])

# %%
model.fit(
      train_generator,
      steps_per_epoch=25,  # berapa batch yang akan dieksekusi pada setiap epoch
      epochs=200,
      validation_data=validation_generator, # menampilkan akurasi pengujian data validasi
      validation_steps=5,  # berapa batch yang akan dieksekusi pada setiap epoch
      verbose=2, callbacks=[callbacks])
# Out:
# Epoch 1/200
# 25/25 - 7s - loss: 0.7794 - accuracy: 0.4800 - val_loss: 0.6900 - val_accuracy: 0.5500
# Epoch 2/200
# 25/25 - 6s - loss: 0.7075 - accuracy: 0.4700 - val_loss: 0.6928 - val_accuracy: 0.5500
# Epoch 3/200
# 25/25 - 6s - loss: 0.6921 - accuracy: 0.5400 - val_loss: 0.6709 - val_accuracy: 0.8000
# Epoch 4/200
# 25/25 - 6s - loss: 0.6251 - accuracy: 0.7200 - val_loss: 0.6067 - val_accuracy: 0.6000
# Epoch 5/200
# 25/25 - 6s - loss: 0.6901 - accuracy: 0.5700 - val_loss: 0.6683 - val_accuracy: 0.6000
# Epoch 6/200
# 25/25 - 6s - loss: 0.6921 - accuracy: 0.5800 - val_loss: 0.7229 - val_accuracy: 0.5000
# Epoch 7/200
# 25/25 - 6s - loss: 0.6742 - accuracy: 0.5600 - val_loss: 0.6951 - val_accuracy: 0.5000
# Epoch 8/200
# 25/25 - 6s - loss: 0.7011 - accuracy: 0.4800 - val_loss: 0.6942 - val_accuracy: 0.5000
# Epoch 9/200
# 25/25 - 6s - loss: 0.6957 - accuracy: 0.4300 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 10/200
# 25/25 - 6s - loss: 0.6902 - accuracy: 0.5600 - val_loss: 0.6885 - val_accuracy: 0.5000
# Epoch 11/200
# 25/25 - 6s - loss: 0.6669 - accuracy: 0.5800 - val_loss: 0.6729 - val_accuracy: 0.7000
# Epoch 12/200
# 25/25 - 6s - loss: 0.6434 - accuracy: 0.7000 - val_loss: 0.5746 - val_accuracy: 0.7000
# Epoch 13/200
# 25/25 - 6s - loss: 0.6923 - accuracy: 0.5600 - val_loss: 0.6802 - val_accuracy: 0.5500
# Epoch 14/200
# 25/25 - 6s - loss: 0.7211 - accuracy: 0.6500 - val_loss: 0.7046 - val_accuracy: 0.5000
# Epoch 15/200
# 25/25 - 6s - loss: 0.7076 - accuracy: 0.5200 - val_loss: 0.6896 - val_accuracy: 0.5000
# Epoch 16/200
# 25/25 - 6s - loss: 0.6835 - accuracy: 0.6700 - val_loss: 0.6712 - val_accuracy: 0.8000
# Epoch 17/200
# 25/25 - 6s - loss: 0.6596 - accuracy: 0.7300 - val_loss: 0.6232 - val_accuracy: 0.6500
# Epoch 18/200
# 25/25 - 6s - loss: 0.6436 - accuracy: 0.6300 - val_loss: 0.7502 - val_accuracy: 0.5000
# Epoch 19/200
# 25/25 - 6s - loss: 0.6282 - accuracy: 0.6100 - val_loss: 0.6035 - val_accuracy: 0.7000
# Epoch 20/200
# 25/25 - 6s - loss: 0.6648 - accuracy: 0.6100 - val_loss: 0.6277 - val_accuracy: 0.6500
# Epoch 21/200
# 25/25 - 6s - loss: 0.6260 - accuracy: 0.7200 - val_loss: 0.5791 - val_accuracy: 0.6500
# Epoch 22/200
# 25/25 - 6s - loss: 0.5980 - accuracy: 0.7000 - val_loss: 0.5549 - val_accuracy: 0.9000
# Epoch 23/200
# 25/25 - 6s - loss: 0.5917 - accuracy: 0.7200 - val_loss: 0.5614 - val_accuracy: 0.7500
# Epoch 24/200
# 25/25 - 6s - loss: 0.4575 - accuracy: 0.7800 - val_loss: 0.3924 - val_accuracy: 0.8500
# Epoch 25/200
# 25/25 - 6s - loss: 0.5682 - accuracy: 0.7400 - val_loss: 0.4929 - val_accuracy: 0.8500
# Epoch 26/200
# 25/25 - 6s - loss: 0.5050 - accuracy: 0.7800 - val_loss: 0.4820 - val_accuracy: 0.7500
# Epoch 27/200
# 25/25 - 6s - loss: 0.4567 - accuracy: 0.7900 - val_loss: 0.4859 - val_accuracy: 0.7500
# Epoch 28/200
# 25/25 - 6s - loss: 0.4682 - accuracy: 0.7900 - val_loss: 0.4641 - val_accuracy: 0.7500
# Epoch 29/200
# 25/25 - 6s - loss: 0.5365 - accuracy: 0.7600 - val_loss: 0.5294 - val_accuracy: 0.7500
# Epoch 30/200
# 25/25 - 6s - loss: 0.4457 - accuracy: 0.8300 - val_loss: 0.7550 - val_accuracy: 0.6500
# Epoch 31/200
# 25/25 - 6s - loss: 0.5574 - accuracy: 0.7500 - val_loss: 0.5235 - val_accuracy: 0.7000
# Epoch 32/200
# 25/25 - 6s - loss: 0.6107 - accuracy: 0.6900 - val_loss: 0.5613 - val_accuracy: 0.7500
# Epoch 33/200
# 25/25 - 6s - loss: 0.5457 - accuracy: 0.7200 - val_loss: 0.5079 - val_accuracy: 0.8000
# Epoch 34/200
# 25/25 - 6s - loss: 0.3778 - accuracy: 0.8400 - val_loss: 0.4194 - val_accuracy: 0.7500
# Epoch 35/200
# 25/25 - 6s - loss: 0.5212 - accuracy: 0.7500 - val_loss: 0.4904 - val_accuracy: 0.8000
# Epoch 36/200
# 25/25 - 6s - loss: 0.4483 - accuracy: 0.8100 - val_loss: 0.4829 - val_accuracy: 0.8000
# Epoch 37/200
# 25/25 - 6s - loss: 0.4534 - accuracy: 0.8000 - val_loss: 0.5432 - val_accuracy: 0.7000
# Epoch 38/200
# 25/25 - 6s - loss: 0.4871 - accuracy: 0.7200 - val_loss: 0.4914 - val_accuracy: 0.7500
# Epoch 39/200
# 25/25 - 6s - loss: 0.4694 - accuracy: 0.7600 - val_loss: 0.4713 - val_accuracy: 0.8500
# Epoch 40/200
# 25/25 - 6s - loss: 0.4415 - accuracy: 0.8100 - val_loss: 0.4981 - val_accuracy: 0.7000
# Epoch 41/200
# 25/25 - 6s - loss: 0.3686 - accuracy: 0.8500 - val_loss: 0.5123 - val_accuracy: 0.8000
# Epoch 42/200
# 25/25 - 6s - loss: 0.4798 - accuracy: 0.7700 - val_loss: 0.4843 - val_accuracy: 0.7500
# Epoch 43/200
# 25/25 - 6s - loss: 0.4577 - accuracy: 0.7500 - val_loss: 0.4990 - val_accuracy: 0.7500
# Epoch 44/200
# 25/25 - 6s - loss: 0.4160 - accuracy: 0.7700 - val_loss: 0.4705 - val_accuracy: 0.8000
# Epoch 45/200
# 25/25 - 6s - loss: 0.4687 - accuracy: 0.8000 - val_loss: 0.4471 - val_accuracy: 0.8000
# Epoch 46/200
# 25/25 - 6s - loss: 0.3809 - accuracy: 0.8700 - val_loss: 0.4739 - val_accuracy: 0.7000
# Epoch 47/200
# 25/25 - 6s - loss: 0.3643 - accuracy: 0.8200 - val_loss: 0.4249 - val_accuracy: 0.7500
# Epoch 48/200
# 25/25 - 6s - loss: 0.3676 - accuracy: 0.8100 - val_loss: 0.5745 - val_accuracy: 0.7000
# Epoch 49/200
# 25/25 - 6s - loss: 0.3332 - accuracy: 0.8400 - val_loss: 0.3418 - val_accuracy: 0.8500
# Epoch 50/200
# 25/25 - 6s - loss: 0.4418 - accuracy: 0.8100 - val_loss: 0.5453 - val_accuracy: 0.7500
# Epoch 51/200
# 25/25 - 6s - loss: 0.4042 - accuracy: 0.7800 - val_loss: 0.4087 - val_accuracy: 0.8000
# Epoch 52/200
# 25/25 - 6s - loss: 0.4014 - accuracy: 0.8000 - val_loss: 0.4112 - val_accuracy: 0.7500
# Epoch 53/200
# 25/25 - 6s - loss: 0.3642 - accuracy: 0.8400 - val_loss: 0.3672 - val_accuracy: 0.8500
# Epoch 54/200
# 25/25 - 6s - loss: 0.2433 - accuracy: 0.9000 - val_loss: 0.5096 - val_accuracy: 0.8000
# Epoch 55/200
# 25/25 - 6s - loss: 0.3770 - accuracy: 0.8400 - val_loss: 0.4689 - val_accuracy: 0.8500
# Epoch 56/200
# 25/25 - 6s - loss: 0.4447 - accuracy: 0.7800 - val_loss: 0.4235 - val_accuracy: 0.7500
# Epoch 57/200
# 25/25 - 6s - loss: 0.3538 - accuracy: 0.8500 - val_loss: 0.3458 - val_accuracy: 0.8500
# Epoch 58/200
# 25/25 - 6s - loss: 0.3031 - accuracy: 0.8300 - val_loss: 0.2035 - val_accuracy: 0.9000
# Epoch 59/200
# 25/25 - 6s - loss: 0.2489 - accuracy: 0.9000 - val_loss: 0.6498 - val_accuracy: 0.7500
# Epoch 60/200
# 25/25 - 6s - loss: 0.3943 - accuracy: 0.8100 - val_loss: 0.5413 - val_accuracy: 0.7500
# Epoch 61/200
# 25/25 - 6s - loss: 0.2382 - accuracy: 0.8800 - val_loss: 0.3853 - val_accuracy: 0.9000
# Epoch 62/200
# 25/25 - 6s - loss: 0.3961 - accuracy: 0.8400 - val_loss: 0.3078 - val_accuracy: 0.9000
# Epoch 63/200
# 25/25 - 6s - loss: 0.3476 - accuracy: 0.8700 - val_loss: 0.7074 - val_accuracy: 0.6500
# Epoch 64/200
# 25/25 - 6s - loss: 0.2442 - accuracy: 0.9000 - val_loss: 0.4294 - val_accuracy: 0.8000
# Epoch 65/200
# 25/25 - 6s - loss: 0.2688 - accuracy: 0.8900 - val_loss: 0.4275 - val_accuracy: 0.8500
# Epoch 66/200
# 25/25 - 6s - loss: 0.2694 - accuracy: 0.9000 - val_loss: 0.5574 - val_accuracy: 0.7500
# Epoch 67/200
# 25/25 - 6s - loss: 0.2730 - accuracy: 0.9100 - val_loss: 0.6678 - val_accuracy: 0.7000
# Epoch 68/200
# 25/25 - 6s - loss: 0.2791 - accuracy: 0.9100 - val_loss: 0.4506 - val_accuracy: 0.7500
# Epoch 69/200
# 25/25 - 6s - loss: 0.1859 - accuracy: 0.9300 - val_loss: 0.4570 - val_accuracy: 0.8500
# Epoch 70/200
# 25/25 - 6s - loss: 0.1801 - accuracy: 0.9300 - val_loss: 0.6921 - val_accuracy: 0.8000
# Epoch 71/200
# 25/25 - 6s - loss: 0.2819 - accuracy: 0.9400 - val_loss: 0.3358 - val_accuracy: 0.8500
# Epoch 72/200
# 25/25 - 6s - loss: 0.1946 - accuracy: 0.9200 - val_loss: 0.5356 - val_accuracy: 0.8000
# Epoch 73/200
# 25/25 - 6s - loss: 0.1722 - accuracy: 0.9200 - val_loss: 0.2482 - val_accuracy: 0.8500
# Epoch 74/200
# 25/25 - 6s - loss: 0.2366 - accuracy: 0.8800 - val_loss: 0.4715 - val_accuracy: 0.7000
# Epoch 75/200
# 25/25 - 6s - loss: 0.1719 - accuracy: 0.9000 - val_loss: 0.5788 - val_accuracy: 0.7000
# Epoch 76/200
# 25/25 - 6s - loss: 0.1125 - accuracy: 0.9800 - val_loss: 0.4620 - val_accuracy: 0.9000
# Epoch 77/200
# 25/25 - 6s - loss: 0.1518 - accuracy: 0.9200 - val_loss: 0.4286 - val_accuracy: 0.7500
# Epoch 78/200
# 25/25 - 6s - loss: 0.1858 - accuracy: 0.9600 - val_loss: 0.4251 - val_accuracy: 0.8500
# Epoch 79/200
# 25/25 - 6s - loss: 0.0840 - accuracy: 0.9600 - val_loss: 0.2221 - val_accuracy: 0.9000
# Epoch 80/200
# 25/25 - 6s - loss: 0.2407 - accuracy: 0.9100 - val_loss: 1.1720 - val_accuracy: 0.7500
# Epoch 81/200
# 25/25 - 6s - loss: 0.2439 - accuracy: 0.8900 - val_loss: 0.1611 - val_accuracy: 0.9000
# Epoch 82/200
# 25/25 - 6s - loss: 0.1602 - accuracy: 0.9400 - val_loss: 0.2330 - val_accuracy: 0.9000
# Epoch 83/200
# 25/25 - 6s - loss: 0.1076 - accuracy: 0.9700 - val_loss: 0.1977 - val_accuracy: 0.9500
#
# Reached 96% accuracy so cancelling training!

# %%
import numpy as np
from google.colab import files
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
 
uploaded = files.upload()
 
for fn in uploaded.keys():
 
  # predicting images
  path = fn
  img = image.load_img(path, target_size=(150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)
 
  images = np.vstack([x])
  classes = model.predict(images, batch_size=10)
  
  print(fn)
  if classes==0:
    print('clean')
  else:
    print('messy')
# Out:
#      <input type="file" id="files-cc97b78d-a844-4fed-9313-200ad0fd129a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cc97b78d-a844-4fed-9313-200ad0fd129a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 1.jpg to 1 (2).jpg
# 1.jpg
# clean

# %%
import numpy as np
from google.colab import files
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
 
uploaded = files.upload()
 
for fn in uploaded.keys():
 
  # predicting images
  path = fn
  img = image.load_img(path, target_size=(150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)
 
  images = np.vstack([x])
  classes = model.predict(images, batch_size=10)
  
  print(fn)
  if classes==0:
    print('clean')
  else:
    print('messy')
# Out:
#      <input type="file" id="files-8431ff55-2d89-4933-a2d0-c5fb6f469958" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8431ff55-2d89-4933-a2d0-c5fb6f469958">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2.jpg to 2.jpg
# 2.jpg
# messy
